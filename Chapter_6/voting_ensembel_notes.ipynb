# %% [markdown]
# In voting ensembel we use multiple different or same models and then we use all the models at the same time and based on their result give the final prediction

# %% [markdown]
# It can be used for both classification as well regression

# %% [markdown]
# ![](Images/voting_intuation.png)

# %% [markdown]
# For voting ensembel to work well there are 2 assumptions that we should consider:
# 1. All the models should be different meaning not prediction same thing for same data the more different the models are the better the result.
# 2. Minimum accuracy of all the models must be greater then 51%

# %% [markdown]
# Based on the probability we can find that the probability of finding the maximum probability will me maximum.

# %% [markdown]
# ## Hard Vs Soft Classifier:

# %% [markdown]
# Hard:

# %% [markdown]
# ![](Images/hard_classifier.png)

# %% [markdown]
# In hard classifier we directly predict the label like 0 in this case

# %% [markdown]
# Soft:

# %% [markdown]
# ![](Images/soft_classifier.png)

# %% [markdown]
# In soft classifier instead of prediciting the label directly the model predict the probability of all the labels by taking their mean and then based on that predict the label

# %% [markdown]
# Mostly soft work better but should try both

# %% [markdown]
# ## Weighted_voting

# %% [markdown]
# We can assign different votes as well to the model if one model as high accuracy we can assign it high weight so it can increase the overall accuracy

# %% [markdown]
# One more approach as mentioned is the code as well we can hv multiple instances of the same model join em to make a better model overall

# %% [markdown]
# ## Voting Regression

# %% [markdown]
# In regression like classification the model will predict a numeric output and we will combine the numeric output of multiple models to predict the final output by taking the mean of all

# %% [markdown]
# ![](Images/voting_regression.png)
